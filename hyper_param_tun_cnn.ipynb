# %% [markdown]
# <a href="https://colab.research.google.com/github/AkliYalaoui/Deceptive-Opinion-Spam-Classification/blob/main/Attention_based_Bidirectional_LSTM_for_Deceptive_Opinion_Spam_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd
import re
import string
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn import preprocessing

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def clean_text(text):

    ## Remove puncuation
    text = text.translate(string.punctuation)

    ## Convert words to lower case and split them
    text = text.lower().split()

    ## Remove stop words
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops and len(w) >= 3]

    text = " ".join(text)

    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)

    text = text.split()
    stemmer = SnowballStemmer('english')
    stemmed_words = [stemmer.stem(word) for word in text]
    text = " ".join(stemmed_words)

    return text

# %%
 # Some preprocesssing that will be common to all the text classification methods

puncts = [',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&', '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£',
 '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',  '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…',
 '“', '★', '”', '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾', '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─',
 '▒', '：', '¼', '⊕', '▼', '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲', 'è', '¸', '¾', 'Ã', '⋅', '‘', '∞',
 '∙', '）', '↓', '、', '│', '（', '»', '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø', '¹', '≤', '‡', '√', ]

def clean_char(x):
    x = str(x)
    for punct in puncts:
        if punct in x:
            x = x.replace(punct, f' {punct} ')
    return x

# %%
def clean_numbers(x):
    if bool(re.search(r'\d', x)):
        x = re.sub('[0-9]{5,}', '#####', x)
        x = re.sub('[0-9]{4}', '####', x)
        x = re.sub('[0-9]{3}', '###', x)
        x = re.sub('[0-9]{2}', '##', x)
    return x

# %% [markdown]
# # 3. Deep Learning Architectures

# %% [markdown]
# ## A. CNN + LSTM + Doc2Vec +TF-IDF

# %%
! pip install np_utils
# Out:
# Requirement already satisfied: np_utils in /usr/local/lib/python3.10/dist-packages (0.6.0)
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.10/dist-packages (from np_utils) (1.23.5)

# %%
import pandas as pd
import numpy as np
from keras.preprocessing import sequence
from keras.layers import TimeDistributed, GlobalAveragePooling1D, GlobalAveragePooling2D, BatchNormalization
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, Conv2D, MaxPooling2D, AveragePooling1D
from keras.layers import Embedding
from keras.layers import Dropout, Flatten, Bidirectional, Dense, Activation, TimeDistributed
from keras.models import Model, Sequential
import np_utils
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from string import ascii_lowercase
from collections import Counter
from gensim.models import Word2Vec
from gensim.models import Doc2Vec
from gensim.models import doc2vec
from gensim.models import KeyedVectors
import itertools, nltk, snowballstemmer, re

LabeledSentence = doc2vec.TaggedDocument

# %%
class LabeledLineSentence(object):
    def __init__(self, sources):
        self.sources = sources

        flipped = {}

        # make sure that keys are unique
        for key, value in sources.items():
            if value not in flipped:
                flipped[value] = [key]
            else:
                raise Exception('Non-unique prefix encountered')

    def __iter__(self):
        for source, prefix in self.sources.items():
            with utils.smart_open(source) as fin:
                for item_no, line in enumerate(fin):
                    yield LabeledSentence(utils.to_unicode(line).split(), [prefix + '_%s' % item_no])

    def to_array(self):
        self.sentences = []
        for source, prefix in self.sources.items():
            with utils.smart_open(source) as fin:
                for item_no, line in enumerate(fin):
                    self.sentences.append(LabeledSentence(utils.to_unicode(line).split(), [prefix + '_%s' % item_no]))
        return self.sentences

    def sentences_perm(self):
        shuffled = list(self.sentences)
        random.shuffle(shuffled)
        return shuffled

# %%
data = pd.read_csv("/content/drive/MyDrive/yelp_data/deceptive-opinion.csv")

# %%
data['polarity'] = np.where(data['polarity']=='positive', 1, 0)
data['deceptive'] = np.where(data['deceptive']=='truthful', 1, 0)

# %%
data.head()
# Out:
#    deceptive   hotel  polarity       source  \
# 0          1  conrad         1  TripAdvisor
# 1          1   hyatt         1  TripAdvisor
# 2          1   hyatt         1  TripAdvisor
# 3          1    omni         1  TripAdvisor
# 4          1   hyatt         1  TripAdvisor
#
#                                                 text
# 0  We stayed for a one night getaway with family ...
# 1  Triple A rate with upgrade to view room was le...
# 2  This comes a little late as I'm finally catchi...
# 3  The Omni Chicago really delivers on all fronts...
# 4  I asked for a high floor away from the elevato...

# %%
df = data.sample(frac=1)
df.head()
# Out:
#       deceptive      hotel  polarity source  \
# 1483          0     monaco         0  MTurk
# 1401          0    affinia         0  MTurk
# 488           0  swissotel         1  MTurk
# 1024          1    affinia         0    Web
# 630           0    affinia         1  MTurk
#
#                                                    text
# 1483  The hotel is located in an hard to fins locati...
# 1401  If you are looking for a high end hotel on the...
# 488   I absolutely loved staying at the Swissotel Ch...
# 1024  Having stayed at the excellent Affinia chain i...
# 630   There were many positives when staying in this...

# %%
df.describe()
# Out:
#          deceptive     polarity
# count  1600.000000  1600.000000
# mean      0.500000     0.500000
# std       0.500156     0.500156
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.500000     0.500000
# 75%       1.000000     1.000000
# max       1.000000     1.000000

# %%
def create_class(c):
    if c['polarity'] == 1 and c['deceptive'] == 1:
        return [1,1]
    elif c['polarity'] == 1 and c['deceptive'] == 0:
        return [1,0]
    elif c['polarity'] == 0 and c['deceptive'] == 1:
        return [0,1]
    else:
        return [0,0]

def specific_class(c):
    if c['polarity'] == 1 and c['deceptive'] == 1:
        return "TRUE_POSITIVE"
    elif c['polarity'] == 1 and c['deceptive'] == 0:
        return "FALSE_POSITIVE"
    elif c['polarity'] == 0 and c['deceptive'] == 1:
        return "TRUE_NEGATIVE"
    else:
        return "FALSE_NEGATIVE"

data['final_class'] = data.apply(create_class, axis=1)
data['given_class'] = data.apply(specific_class, axis=1)

# %%
data.head()
# Out:
#    deceptive   hotel  polarity       source  \
# 0          1  conrad         1  TripAdvisor
# 1          1   hyatt         1  TripAdvisor
# 2          1   hyatt         1  TripAdvisor
# 3          1    omni         1  TripAdvisor
# 4          1   hyatt         1  TripAdvisor
#
#                                                 text final_class  \
# 0  We stayed for a one night getaway with family ...      [1, 1]
# 1  Triple A rate with upgrade to view room was le...      [1, 1]
# 2  This comes a little late as I'm finally catchi...      [1, 1]
# 3  The Omni Chicago really delivers on all fronts...      [1, 1]
# 4  I asked for a high floor away from the elevato...      [1, 1]
#
#      given_class
# 0  TRUE_POSITIVE
# 1  TRUE_POSITIVE
# 2  TRUE_POSITIVE
# 3  TRUE_POSITIVE
# 4  TRUE_POSITIVE

# %%
# Import label encoder
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
data['given_class']= label_encoder.fit_transform(data['given_class'])

data['given_class'].unique()
# Out:
# array([3, 1, 2, 0])

# %%
from tensorflow.keras.utils import to_categorical

Y = data['given_class']
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = to_categorical(encoded_Y)

# %%
textData = pd.DataFrame(list(data['text']))

stemmer = snowballstemmer.EnglishStemmer()

# grab stopword list, extend it a bit, and then turn it into a set for later
stop = stopwords.words('english')
stop.extend(['may','also','zero','one','two','three','four','five','six','seven','eight','nine','ten','across','among','beside','however','yet','within']+list(ascii_lowercase))
stoplist = stemmer.stemWords(stop)
stoplist = set(stoplist)
stop = set(sorted(stop + list(stoplist)))

# %%
textData[0].replace('[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’”“′‘\\\]',' ',inplace=True,regex=True)
wordlist = filter(None, " ".join(list(set(list(itertools.chain(*textData[0].str.split(' ')))))).split(" "))
data['stemmed_text_data'] = [' '.join(filter(None,filter(lambda word: word not in stop, line))) for line in textData[0].str.lower().str.split(' ')]

# %%
# remove all words that don't occur at least 5 times and then stem the resulting docs
minimum_count = 1
str_frequencies = pd.DataFrame(list(Counter(filter(None,list(itertools.chain(*data['stemmed_text_data'].str.split(' '))))).items()),columns=['word','count'])
low_frequency_words = set(str_frequencies[str_frequencies['count'] < minimum_count]['word'])
data['stemmed_text_data'] = [' '.join(filter(None,filter(lambda word: word not in low_frequency_words, line))) for line in data['stemmed_text_data'].str.split(' ')]
data['stemmed_text_data'] = [" ".join(stemmer.stemWords(re.sub('[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’”“′‘\\\]',' ', next_text).split(' '))) for next_text in data['stemmed_text_data']]

# %%
lmtzr = WordNetLemmatizer()
w = re.compile("\w+",re.I)

def label_sentences(df, input_point):
    labeled_sentences = []
    list_sen = []
    for index, datapoint in df.iterrows():
        tokenized_words = re.findall(w,datapoint[input_point].lower())
        labeled_sentences.append(LabeledSentence(words=tokenized_words, tags=['SENT_%s' %index]))
        list_sen.append(tokenized_words)
    return labeled_sentences, list_sen

def train_doc2vec_model(labeled_sentences):
    model = Doc2Vec(min_count=1, window=9, vector_size=512, sample=1e-4, negative=5, workers=7)
    model.build_vocab(labeled_sentences)
    pretrained_weights = model.wv.vectors
    vocab_size, embedding_size = pretrained_weights.shape
    model.train(labeled_sentences, total_examples=vocab_size, epochs=400)

    return model

# %%
textData = data['stemmed_text_data'].to_frame().reset_index()
sen, corpus = label_sentences(textData, 'stemmed_text_data')

# %%
doc2vec_model = train_doc2vec_model(sen)
# Out:
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 1: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 2: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 3: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 4: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 5: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 6: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 7: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 8: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 9: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 10: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 11: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 12: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 13: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 14: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 15: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 16: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 17: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 18: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 19: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 20: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 21: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 22: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 23: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 24: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 25: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 26: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 27: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 28: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 29: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 30: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 31: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 32: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 33: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 34: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 35: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 36: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 37: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 38: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 39: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 40: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 41: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 42: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 43: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 44: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 45: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 46: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 47: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 48: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 49: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 50: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 51: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 52: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 53: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 54: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 55: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 56: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 57: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 58: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 59: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 60: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 61: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 62: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 63: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 64: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 65: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 66: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 67: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 68: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 69: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 70: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 71: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 72: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 73: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 74: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 75: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 76: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 77: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 78: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 79: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 80: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 81: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 82: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 83: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 84: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 85: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 86: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 87: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 88: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 89: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 90: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 91: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 92: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 93: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 94: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 95: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 96: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 97: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 98: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 99: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 100: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 101: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 102: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 103: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 104: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 105: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 106: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 107: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 108: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 109: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 110: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 111: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 112: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 113: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 114: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 115: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 116: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 117: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 118: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 119: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 120: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 121: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 122: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 123: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 124: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 125: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 126: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 127: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 128: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 129: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 130: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 131: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 132: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 133: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 134: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 135: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 136: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 137: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 138: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 139: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 140: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 141: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 142: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 143: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 144: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 145: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 146: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 147: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 148: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 149: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 150: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 151: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 152: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 153: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 154: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 155: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 156: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 157: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 158: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 159: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 160: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 161: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 162: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 163: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 164: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 165: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 166: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 167: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 168: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 169: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 170: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 171: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 172: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 173: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 174: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 175: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 176: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 177: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 178: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 179: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 180: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 181: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 182: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 183: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 184: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 185: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 186: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 187: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 188: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 189: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 190: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 191: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 192: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 193: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 194: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 195: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 196: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 197: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 198: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 199: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 200: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 201: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 202: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 203: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 204: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 205: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 206: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 207: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 208: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 209: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 210: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 211: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 212: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 213: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 214: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 215: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 216: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 217: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 218: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 219: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 220: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 221: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 222: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 223: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 224: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 225: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 226: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 227: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 228: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 229: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 230: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 231: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 232: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 233: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 234: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 235: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 236: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 237: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 238: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 239: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 240: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 241: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 242: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 243: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 244: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 245: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 246: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 247: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 248: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 249: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 250: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 251: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 252: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 253: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 254: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 255: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 256: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 257: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 258: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 259: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 260: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 261: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 262: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 263: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 264: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 265: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 266: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 267: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 268: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 269: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 270: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 271: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 272: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 273: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 274: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 275: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 276: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 277: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 278: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 279: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 280: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 281: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 282: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 283: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 284: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 285: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 286: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 287: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 288: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 289: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 290: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 291: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 292: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 293: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 294: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 295: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 296: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 297: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 298: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 299: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 300: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 301: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 302: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 303: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 304: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 305: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 306: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 307: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 308: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 309: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 310: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 311: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 312: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 313: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 314: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 315: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 316: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 317: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 318: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 319: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 320: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 321: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 322: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 323: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 324: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 325: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 326: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 327: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 328: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 329: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 330: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 331: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 332: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 333: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 334: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 335: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 336: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 337: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 338: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 339: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 340: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 341: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 342: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 343: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 344: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 345: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 346: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 347: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 348: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 349: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 350: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 351: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 352: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 353: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 354: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 355: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 356: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 357: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 358: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 359: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 360: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 361: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 362: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 363: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 364: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 365: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 366: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 367: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 368: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 369: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 370: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 371: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 372: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 373: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 374: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 375: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 376: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 377: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 378: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 379: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 380: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 381: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 382: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 383: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 384: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 385: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 386: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 387: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 388: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 389: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 390: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 391: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 392: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 393: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 394: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 395: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 396: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 397: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 398: supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.word2vec:EPOCH 399: supplied example count (1600) did not equal expected count (6269)

# %%
doc2vec_model.save("doc2vec_model_opinion_corpus.d2v")

# %%
doc2vec_model = Doc2Vec.load("doc2vec_model_opinion_corpus.d2v")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

tfidf1 = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False, ngram_range=(1,1))
result_train1 = tfidf1.fit_transform(corpus)

tfidf2 = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False, ngram_range=(1,2))
result_train2 = tfidf2.fit_transform(corpus)

tfidf3 = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False, ngram_range=(1,3))
result_train3 = tfidf3.fit_transform(corpus)

svd = TruncatedSVD(n_components=512, n_iter=40, random_state=34)
tfidf_data1 = svd.fit_transform(result_train1)
tfidf_data2 = svd.fit_transform(result_train2)
tfidf_data3 = svd.fit_transform(result_train3)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
from sklearn.feature_extraction.text import CountVectorizer
import spacy

nlp = spacy.load('en_core_web_sm')
temp_textData = pd.DataFrame(list(data['text']))

overall_pos_tags_tokens = []
overall_pos = []
overall_tokens = []
overall_dep = []

for i in range(1600):
    doc = nlp(temp_textData[0][i])
    given_pos_tags_tokens = []
    given_pos = []
    given_tokens = []
    given_dep = []
    for token in doc:
        output = "%s_%s" % (token.pos_, token.tag_)
        given_pos_tags_tokens.append(output)
        given_pos.append(token.pos_)
        given_tokens.append(token.tag_)
        given_dep.append(token.dep_)

    overall_pos_tags_tokens.append(given_pos_tags_tokens)
    overall_pos.append(given_pos)
    overall_tokens.append(given_tokens)
    overall_dep.append(given_dep)

# %%
from sklearn.preprocessing import MinMaxScaler

count = CountVectorizer(tokenizer=lambda i:i, lowercase=False)
pos_tags_data = np.asarray(count.fit_transform(overall_pos_tags_tokens).todense())
pos_data = np.asarray(count.fit_transform(overall_pos).todense())
tokens_data = np.asarray(count.fit_transform(overall_tokens).todense())
dep_data = np.asarray(count.fit_transform(overall_dep).todense())
min_max_scaler = MinMaxScaler()
normalized_pos_tags_data = min_max_scaler.fit_transform(pos_tags_data)
normalized_pos_data = min_max_scaler.fit_transform(pos_data)
normalized_tokens_data = min_max_scaler.fit_transform(tokens_data)
normalized_dep_data = min_max_scaler.fit_transform(dep_data)

final_pos_tags_data = np.zeros(shape=(1600, 512)).astype(np.float32)
final_pos_data = np.zeros(shape=(1600, 512)).astype(np.float32)
final_tokens_data = np.zeros(shape=(1600, 512)).astype(np.float32)
final_dep_data = np.zeros(shape=(1600, 512)).astype(np.float32)
final_pos_tags_data[:normalized_pos_tags_data.shape[0],:normalized_pos_tags_data.shape[1]] = normalized_pos_tags_data
final_pos_data[:normalized_pos_data.shape[0],:normalized_pos_data.shape[1]] = normalized_pos_data
final_tokens_data[:normalized_tokens_data.shape[0],:normalized_tokens_data.shape[1]] = normalized_tokens_data
final_dep_data[:normalized_dep_data.shape[0],:normalized_dep_data.shape[1]] = normalized_dep_data
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
pos_tags_data
# Out:
# array([[ 0, 13,  0, ...,  0,  0,  0],
#        [ 0,  5,  1, ...,  0,  0,  0],
#        [ 0, 19,  1, ...,  0,  0,  0],
#        ...,
#        [ 0,  7,  1, ...,  0,  0,  0],
#        [ 0,  3,  1, ...,  0,  0,  0],
#        [ 0, 14,  5, ...,  0,  0,  0]])

# %%
maxlength = []
for i in range(0,len(sen)):
    maxlength.append(len(sen[i][0]))

print(max(maxlength))
# Out:
# 370

# %%
def vectorize_comments(df,d2v_model):
    y = []
    comments = []
    for i in range(0,df.shape[0]):
        label = 'SENT_%s' %i
        comments.append(d2v_model.dv[label])
    df['vectorized_comments'] = comments

    return df

textData = vectorize_comments(textData,doc2vec_model)
print (textData.head(2))
# Out:
#    index                                  stemmed_text_data  \
# 0      0  stay night getaway famili thursday tripl aaa r...
# 1      1  tripl rate upgrad view room less $ includ brea...
#
#                                  vectorized_comments
# 0  [0.31865752, -0.52260464, 0.5098638, 0.2456562...
# 1  [-0.09113293, -0.16862324, 0.49210653, 0.11928...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate,GridSearchCV

X_train, X_test, y_train, y_test = train_test_split(textData["vectorized_comments"].T.tolist(),
                                                                     dummy_y,
                                                                     test_size=0.1,
                                                                     random_state=56)

# %%
X = np.array(textData["vectorized_comments"].T.tolist()).reshape((1,1600,512))
y = np.array(dummy_y).reshape((1600,4))
X_train2 = np.array(X_train).reshape((1,1440,512))
y_train2 = np.array(y_train).reshape((1,1440,4))
X_test2 = np.array(X_test).reshape((1,160,512))
y_test2 = np.array(y_test).reshape((1,160,4))

# %%
from sklearn.model_selection import StratifiedKFold
Xtemp = textData["vectorized_comments"].T.tolist()
ytemp = data['given_class']
training_indices = []
testing_indices = []

skf = StratifiedKFold(n_splits=10)
skf.get_n_splits(Xtemp, ytemp)

for train_index, test_index in skf.split(Xtemp, ytemp):
    training_indices.append(train_index)
    testing_indices.append(test_index)

# %%
def extractTrainingAndTestingData(givenIndex):
    X_train3 = np.zeros(shape=(1440, max(maxlength)+10, 512)).astype(np.float32)
    Y_train3 = np.zeros(shape=(1440, 4)).astype(np.float32)
    X_test3 = np.zeros(shape=(160, max(maxlength)+10, 512)).astype(np.float32)
    Y_test3 = np.zeros(shape=(160, 4)).astype(np.float32)

    empty_word = np.zeros(512).astype(np.float32)

    count_i = 0
    for i in training_indices[givenIndex]:
        len1 = len(sen[i][0])
        average_vector1 = np.zeros(512).astype(np.float32)
        average_vector2 = np.zeros(512).astype(np.float32)
        average_vector3 = np.zeros(512).astype(np.float32)
        for j in range(max(maxlength)+10):
            if j < len1:
                X_train3[count_i,j,:] = doc2vec_model[sen[i][0][j]]
                average_vector1 += result_train1[i, tfidf1.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
                average_vector2 += result_train2[i, tfidf2.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
                average_vector3 += result_train3[i, tfidf3.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
            #elif j >= len1 and j < len1 + 379:
            #    X_train3[count_i,j,:] = glove_data[i, j-len1, :]
            elif j == len1:
                X_train3[count_i,j,:] = tfidf_data1[i]
            elif j == len1 + 1:
                X_train3[count_i,j,:] = tfidf_data2[i]
            elif j == len1+2:
                X_train3[count_i,j,:] = tfidf_data3[i]
            elif j == len1+3:
                X_train3[count_i,j,:] = average_vector1
            elif j == len1+4:
                X_train3[count_i,j,:] = average_vector2
            elif j == len1+5:
                X_train3[count_i,j,:] = average_vector3
            elif j == len1+6:
                X_train3[count_i,j,:] = final_pos_tags_data[i]
            elif j == len1+7:
                X_train3[count_i,j,:] = final_pos_data[i]
            elif j == len1+8:
                X_train3[count_i,j,:] = final_tokens_data[i]
            elif j == len1+9:
                X_train3[count_i,j,:] = final_dep_data[i]
            else:
                X_train3[count_i,j,:] = empty_word

        Y_train3[count_i,:] = dummy_y[i]
        count_i += 1


    count_i = 0
    for i in testing_indices[givenIndex]:
        len1 = len(sen[i][0])
        average_vector1 = np.zeros(512).astype(np.float32)
        average_vector2 = np.zeros(512).astype(np.float32)
        average_vector3 = np.zeros(512).astype(np.float32)
        for j in range(max(maxlength)+10):
            if j < len1:
                X_test3[count_i,j,:] = doc2vec_model[sen[i][0][j]]
                average_vector1 += result_train1[i, tfidf1.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
                average_vector2 += result_train2[i, tfidf2.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
                average_vector3 += result_train3[i, tfidf3.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
            #elif j >= len1 and j < len1 + 379:
            #    X_test3[count_i,j,:] = glove_data[i, j-len1, :]
            elif j == len1:
                X_test3[count_i,j,:] = tfidf_data1[i]
            elif j == len1 + 1:
                X_test3[count_i,j,:] = tfidf_data2[i]
            elif j == len1+2:
                X_test3[count_i,j,:] = tfidf_data3[i]
            elif j == len1+3:
                X_test3[count_i,j,:] = average_vector1
            elif j == len1+4:
                X_test3[count_i,j,:] = average_vector2
            elif j == len1+5:
                X_test3[count_i,j,:] = average_vector3
            elif j == len1+6:
                X_test3[count_i,j,:] = final_pos_tags_data[i]
            elif j == len1+7:
                X_test3[count_i,j,:] = final_pos_data[i]
            elif j == len1+8:
                X_test3[count_i,j,:] = final_tokens_data[i]
            elif j == len1+9:
                X_test3[count_i,j,:] = final_dep_data[i]
            else:
                X_test3[count_i,j,:] = empty_word

        Y_test3[count_i,:] = dummy_y[i]
        count_i += 1

    return X_train3, X_test3, Y_train3, Y_test3

# %%
model = Sequential()
model.add(Conv1D(filters=128, kernel_size=9, padding='same', activation='relu', input_shape=(max(maxlength)+10,512)))
model.add(Dropout(0.25))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv1D(filters=128, kernel_size=7, padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))
model.add(Conv1D(filters=128, kernel_size=5, padding='same', activation='relu'))
model.add(Dropout(0.25))

model.add(Bidirectional(LSTM(50, dropout=0.25, recurrent_dropout=0.2)))
model.add(Dense(4, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
print(model.summary())
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 380, 128)          589952
#
#  dropout (Dropout)           (None, 380, 128)          0
#
#  max_pooling1d (MaxPooling1  (None, 190, 128)          0
#  D)
#
#  dropout_1 (Dropout)         (None, 190, 128)          0
#
#  conv1d_1 (Conv1D)           (None, 190, 128)          114816
#
#  dropout_2 (Dropout)         (None, 190, 128)          0
#
#  max_pooling1d_1 (MaxPoolin  (None, 95, 128)           0
#  g1D)
#
#  dropout_3 (Dropout)         (None, 95, 128)           0
#
#  conv1d_2 (Conv1D)           (None, 95, 128)           82048
#
#  dropout_4 (Dropout)         (None, 95, 128)           0
#
#  bidirectional (Bidirection  (None, 100)               71600
#  al)
#
#  dense (Dense)               (None, 4)                 404
#
# =================================================================
# Total params: 858820 (3.28 MB)
# Trainable params: 858820 (3.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
from sklearn.metrics import accuracy_score
from keras.callbacks import ModelCheckpoint

final_accuracies = []

filename = 'weights.best.from_scratch%s.hdf5' % 9
checkpointer = ModelCheckpoint(filepath=filename, verbose=1, save_best_only=True)
X_train3, X_test3, Y_train3, Y_test3 = extractTrainingAndTestingData(9)

# %%
history = model.fit(X_train3, Y_train3, epochs=15, batch_size=512, callbacks=[checkpointer], validation_data=(X_test3, Y_test3), verbose=1)
# Out:
# Epoch 1/15
# 3/3 [==============================] - ETA: 0s - loss: 0.6192 - accuracy: 0.2514
# Epoch 1: val_loss improved from inf to 0.56089, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 26s 4s/step - loss: 0.6192 - accuracy: 0.2514 - val_loss: 0.5609 - val_accuracy: 0.2750
# Epoch 2/15
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 3/3 [==============================] - ETA: 0s - loss: 0.5618 - accuracy: 0.2972
# Epoch 2: val_loss improved from 0.56089 to 0.55720, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.5618 - accuracy: 0.2972 - val_loss: 0.5572 - val_accuracy: 0.2625
# Epoch 3/15
# 3/3 [==============================] - ETA: 0s - loss: 0.5554 - accuracy: 0.3306
# Epoch 3: val_loss improved from 0.55720 to 0.53552, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 4s 2s/step - loss: 0.5554 - accuracy: 0.3306 - val_loss: 0.5355 - val_accuracy: 0.3812
# Epoch 4/15
# 3/3 [==============================] - ETA: 0s - loss: 0.5312 - accuracy: 0.4174
# Epoch 4: val_loss improved from 0.53552 to 0.48784, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.5312 - accuracy: 0.4174 - val_loss: 0.4878 - val_accuracy: 0.6313
# Epoch 5/15
# 3/3 [==============================] - ETA: 0s - loss: 0.4940 - accuracy: 0.5215
# Epoch 5: val_loss improved from 0.48784 to 0.46010, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.4940 - accuracy: 0.5215 - val_loss: 0.4601 - val_accuracy: 0.6313
# Epoch 6/15
# 3/3 [==============================] - ETA: 0s - loss: 0.4643 - accuracy: 0.5674
# Epoch 6: val_loss improved from 0.46010 to 0.43581, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.4643 - accuracy: 0.5674 - val_loss: 0.4358 - val_accuracy: 0.6375
# Epoch 7/15
# 3/3 [==============================] - ETA: 0s - loss: 0.4387 - accuracy: 0.5792
# Epoch 7: val_loss improved from 0.43581 to 0.41323, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 4s 1s/step - loss: 0.4387 - accuracy: 0.5792 - val_loss: 0.4132 - val_accuracy: 0.6625
# Epoch 8/15
# 3/3 [==============================] - ETA: 0s - loss: 0.4117 - accuracy: 0.6729
# Epoch 8: val_loss improved from 0.41323 to 0.38476, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.4117 - accuracy: 0.6729 - val_loss: 0.3848 - val_accuracy: 0.7312
# Epoch 9/15
# 3/3 [==============================] - ETA: 0s - loss: 0.3836 - accuracy: 0.7347
# Epoch 9: val_loss improved from 0.38476 to 0.35513, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.3836 - accuracy: 0.7347 - val_loss: 0.3551 - val_accuracy: 0.7875
# Epoch 10/15
# 3/3 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.7618
# Epoch 10: val_loss improved from 0.35513 to 0.34330, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.3586 - accuracy: 0.7618 - val_loss: 0.3433 - val_accuracy: 0.7625
# Epoch 11/15
# 3/3 [==============================] - ETA: 0s - loss: 0.3346 - accuracy: 0.7819
# Epoch 11: val_loss improved from 0.34330 to 0.32256, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 4s 2s/step - loss: 0.3346 - accuracy: 0.7819 - val_loss: 0.3226 - val_accuracy: 0.7750
# Epoch 12/15
# 3/3 [==============================] - ETA: 0s - loss: 0.3146 - accuracy: 0.8042
# Epoch 12: val_loss improved from 0.32256 to 0.31537, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.3146 - accuracy: 0.8042 - val_loss: 0.3154 - val_accuracy: 0.7437
# Epoch 13/15
# 3/3 [==============================] - ETA: 0s - loss: 0.2953 - accuracy: 0.8111
# Epoch 13: val_loss improved from 0.31537 to 0.29450, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.2953 - accuracy: 0.8111 - val_loss: 0.2945 - val_accuracy: 0.7937
# Epoch 14/15
# 3/3 [==============================] - ETA: 0s - loss: 0.2726 - accuracy: 0.8424
# Epoch 14: val_loss improved from 0.29450 to 0.28825, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 3s 1s/step - loss: 0.2726 - accuracy: 0.8424 - val_loss: 0.2883 - val_accuracy: 0.7437
# Epoch 15/15
# 3/3 [==============================] - ETA: 0s - loss: 0.2603 - accuracy: 0.8424
# Epoch 15: val_loss improved from 0.28825 to 0.26362, saving model to weights.best.from_scratch9.hdf5
# 3/3 [==============================] - 4s 1s/step - loss: 0.2603 - accuracy: 0.8424 - val_loss: 0.2636 - val_accuracy: 0.8062

# %%
model.evaluate(X_test3, Y_test3)
# Out:
# 5/5 [==============================] - 1s 66ms/step - loss: 0.2636 - accuracy: 0.8062
# [0.2636205554008484, 0.8062499761581421]

# %%
import matplotlib.pyplot as plt

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Hyper Parm tuning

# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras) (23.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.2.0)

# %%
from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score

# %%
# Define a function to create the model
def create_model(optimizer='adam', filters=128, kernel_size=5, lstm_units=50,
                 dense_units=128, dropout_rate=0.25):
    model = Sequential()
    model.add(Conv1D(filters=filters, kernel_size=9, padding='same', activation='relu', input_shape=(max(maxlength)+10,512)))
    model.add(Dropout(dropout_rate))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    model.add(Conv1D(filters=filters, kernel_size=7, padding='same', activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout_rate))
    model.add(Conv1D(filters=filters, kernel_size=5, padding='same', activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Bidirectional(LSTM(lstm_units, dropout=dropout_rate, recurrent_dropout=0.2)))
    model.add(Dense(4, activation='softmax'))
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# Create KerasClassifier
model = KerasClassifier(build_fn=create_model, verbose=0, filters=64, kernel_size=3, lstm_units=50)

# Define the grid search parameters
param_grid = {
    'optimizer': ['adam'],
    'lstm_units': [50, 75, 100],
    'dropout_rate': [0.1, 0.2, 0.3],
}

# Perform random search
grid = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_jobs=-1, cv=3, scoring='accuracy')
grid_result = grid.fit(X_train3, Y_train3)

# Print results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:305: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
